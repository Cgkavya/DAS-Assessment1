# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd

# %%
housing = fetch_california_housing(as_frame=True)
df = housing.frame

# %%
print(df.head())
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
#Display the first 5 rows.

df.head(5)
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
# Print the column names and their data types.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
# Check for missing values in the dataset.

df.isna()
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0       False     False     False      False       False     False     False
# 1       False     False     False      False       False     False     False
# 2       False     False     False      False       False     False     False
# 3       False     False     False      False       False     False     False
# 4       False     False     False      False       False     False     False
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635   False     False     False      False       False     False     False
# 20636   False     False     False      False       False     False     False
# 20637   False     False     False      False       False     False     False
# 20638   False     False     False      False       False     False     False
# 20639   False     False     False      False       False     False     False
#
#        Longitude  MedHouseVal
# ...

# %%
# Get basic statistical summaries using .describe().

df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
# Check for and remove any duplicated rows.

df = df.drop_duplicates()

# %%
# Handle missing values if any: Fill missing numerical features with the mean value.

df['MedInc'] = df['MedInc'].fillna(df['MedInc'].mean())
df['HouseAge'] = df['HouseAge'].fillna(df['HouseAge'].mean())
df['AveRooms'] = df['AveRooms'].fillna(df['AveRooms'].mean())
df['AveBedrms'] = df['AveBedrms'].fillna(df['AveBedrms'].mean())
df['Population'] = df['Population'].fillna(df['Population'].mean())
df['AveOccup'] = df['AveOccup'].fillna(df['AveOccup'].mean())
df['Latitude'] = df['Latitude'].fillna(df['Latitude'].mean())
df['Longitude'] = df['Longitude'].fillna(df['Longitude'].mean())
df['MedHouseVal'] = df['MedHouseVal'].fillna(df['MedHouseVal'].mean())

# %%
# Create a new column PricePerRoom = median_house_value / total_rooms.

df['PricePerRoom'] = df['MedHouseVal'] / df['AveRooms']

# %%
#  Create a column HighPopulationArea: 1 if population > 500, else 0

df['HighPopulationArea'] = [1 if x > 500 else 0 for x in df['Population']]

# %%
# Bin the median_income into 5 equal-sized bins and label them as Very Low, Low, Medium,High, Very High.

bins = [0, 20, 40, 60, 80, 100]
lab = ['Very Low', 'Low', 'Medium', 'High', 'Very High']
df["IncomeCategories"] = pd.cut(df['MedInc'], bins = bins, labels = lab, include_lowest = True)

# %%
#  Drop columns that seem redundant after feature creation (if any).
df
# df.drop(df['HighPopulationArea'])
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
# Plot the distribution of median_house_value with a histogram.

plt.hist(df['MedHouseVal'], color = "green", rwidth = 0.8, density = True)
plt.xlabel('X-axis')
plt.ylabel('Y-Axis')
plt.title('Histogram of median_house_value')
plt.show()

# %%
# Create a scatter plot of longitude vs latitude, colored by median_house_value.

plt.figure(figsize=(5,3.5))
plt.scatter(df['Latitude'], df['Longitude'], c = df['MedHouseVal'], marker = "*")
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.title('Latitude vs Longitude')
plt.show()

# %%
#  Plot a boxplot of median_house_value grouped by the new income categories

import seaborn as sns 
sns.boxplot (x = df['MedHouseVal'], 
            hue = df['IncomeCategories'])
# Out:
# <Axes: xlabel='MedHouseVal'>

# %%
#  Plot the correlation matrix heatmap between numerical features

co_mtx = df.corr(numeric_only=True)
print(co_mtx)
sns.heatmap(co_mtx, cmap="YlGnBu", annot=True)
plt.show()
# Out:
#                       MedInc  HouseAge  AveRooms  AveBedrms  Population  \
# MedInc              1.000000 -0.119034  0.326895  -0.062040    0.004834
# HouseAge           -0.119034  1.000000 -0.153277  -0.077747   -0.296244
# AveRooms            0.326895 -0.153277  1.000000   0.847621   -0.072213
# AveBedrms          -0.062040 -0.077747  0.847621   1.000000   -0.066197
# Population          0.004834 -0.296244 -0.072213  -0.066197    1.000000
# AveOccup            0.018766  0.013191 -0.004852  -0.006181    0.069863
# Latitude           -0.079809  0.011173  0.106389   0.069721   -0.108785
# Longitude          -0.015176 -0.108197 -0.027540   0.013344    0.099773
# MedHouseVal         0.688075  0.105623  0.151948  -0.046701   -0.024650
# PricePerRoom        0.303433  0.194376 -0.172843  -0.128784    0.004976
# HighPopulationArea  0.006571 -0.057568 -0.146521  -0.171236    0.321316
#
#                     AveOccup  Latitude  Longitude  MedHouseVal  PricePerRoom  \
# ...

# %%
# Create a bar plot showing average median_house_value for high population vs low population areas.

import numpy as np
#sns.barplot(x = 'MedHouseVal',
            #data = df,
            #hue = 'Population',
            #estimator = np.median,
            #)
#plt.show()

# %%
# Create a pairplot (sns.pairplot) for selected features: median_income, housing_median_age,median_house_value.

#sns.pairplot(df[['HouseAge'],['MedHouseVal'], ['MedInc']])
#plt.show()
